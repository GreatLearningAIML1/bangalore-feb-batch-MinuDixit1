# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
# importing pandas and numpy
import pandas as pd
import numpy as np
Iris = pd.read_csv("Iris_external-1.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#datatypes of all columns
Iris.dtypes

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
Iris.head(10)

# %%
Iris.tail(10)

# %% [markdown]
# ### Find the shape of the dataset

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.index = Iris['Sepal Length (in cm)']
Iris.head()

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,[2]]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.loc[:,["Sepal Width in (cm)","Sepal Length (in cm)"]].head(10)

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris.loc[Iris["Class"] == "Iris-setosa", :]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra'] = Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)']
Iris

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()

# %%
Iris.var()

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def printf(a,b):
    print(a, '\n' , b)

# %%
#printf((Iris.iloc[4,[0]]) , (Iris.loc[4,[1]]))
a = (Iris.iloc[4,[0]])
b = (Iris.iloc[4,[1]])
printf(a,b)

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#Range = range_calc(5,4)
#x = Iris.iloc[:,[0]]
#x.max()

x = 0
while x<4:
    col = Iris.iloc[:,[x]]
    max1 = col.max()
    min1 = col.min()
    range1 = max1 - min1
    print("Range of " , range1)
    x = x + 1

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values(by=["Petal width (in cm)"])

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[0:10,0:3]
IrisSubset

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
DataTxt = pd.read_csv('HR_external-1.txt', sep="\t", header=None, index_col=0)
headers = DataTxt.iloc[0]
DataTxt  = pd.DataFrame(DataTxt.values[1:], columns=headers)
DataTxt

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
DataTxt.head()
# Out:
# Individual  Attrition Age BusinessTravel DailyRate Department  \
# 0                 Yes  41              1      1102          1
# 1                  No  49              2       279          2
# 2                 Yes  37              1      1373          2
# 3                  No  33              2      1392          2
# 4                  No  27              1       591          2
#
# Individual  DistanceFromHome Education EducationField EmployeeCount  \
# 0                          1         2              1             1
# 1                          8         1              1             1
# 2                          2         2              6             1
# 3                          3         4              1             1
# 4                          2         1              2             1
#
# Individual  EmployeeNumber         ...          RelationshipSatisfaction  \
# 0                        1         ...                                 1
# 1                        2         ...                                 4
# 2                        4         ...                                 2
# 3                        5         ...                                 3
# 4                        7         ...                                 4
#
# Individual  StandardHours StockOptionLevel TotalWorkingYears  \
# 0                      80                0                 8
# 1                      80                1                10
# 2                      80                0                 7
# 3                      80                0                 8
# 4                      80                1                 6
#
# Individual  TrainingTimesLastYear WorkLifeBalance YearsAtCompany  \
# 0                               0               1              6
# 1                               3               3             10
# 2                               3               3              0
# 3                               3               3              8
# 4                               3               3              2
#
# Individual  YearsInCurrentRole YearsSinceLastPromotion YearsWithCurrManager
# 0                            4                       0                    5
# 1                            7                       1                    7
# 2                            0                       0                    0
# 3                            7                       3                    0
# 4                            2                       2                    2
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
DataTxt.dtypes
# Out:
# Individual
# Attrition                   object
# Age                         object
# BusinessTravel              object
# DailyRate                   object
# Department                  object
# DistanceFromHome            object
# Education                   object
# EducationField              object
# EmployeeCount               object
# EmployeeNumber              object
# EnvironmentSatisfaction     object
# Gender                      object
# HourlyRate                  object
# JobInvolvement              object
# JobLevel                    object
# JobRole                     object
# JobSatisfaction             object
# MaritalStatus               object
# MonthlyIncome               object
# MonthlyRate                 object
# NumCompaniesWorked          object
# OverTime                    object
# PercentSalaryHike           object
# PerformanceRating           object
# RelationshipSatisfaction    object
# StandardHours               object
# StockOptionLevel            object
# TotalWorkingYears           object
# TrainingTimesLastYear       object
# WorkLifeBalance             object
# YearsAtCompany              object
# YearsInCurrentRole          object
# YearsSinceLastPromotion     object
# YearsWithCurrManager        object
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
DataTxt.iloc[:,2:10]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
x = DataTxt.Gender.value_counts()
print(x)
print("The total number of employees in the company are " , 882+588)

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
DataTxt['Age'].quantile(.75) - DataTxt['Age'].quantile(.25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-9106c7650356> in <module>
# ----> 1 DataTxt['Age'].quantile(.75) - DataTxt['Age'].quantile(.25)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    1876         self._check_percentile(q)
#    1877
# -> 1878         result = self._data.quantile(qs=q, interpolation=interpolation)
#    1879
#    1880         if is_list_like(q):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in quantile(self, **kwargs)
#    3688
#    3689     def quantile(self, **kwargs):
# -> 3690         return self.reduction('quantile', **kwargs)
#    3691
#    3692     def setitem(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in reduction(self, f, axis, consolidate, transposed, **kwargs)
#    3617         for b in self.blocks:
#    3618             kwargs['mgr'] = self
# -> 3619             axe, block = getattr(b, f)(axis=axis, **kwargs)
#    3620
#    3621             axes.append(axe)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in quantile(self, qs, interpolation, axis, mgr)
#    1681                     result = np.array([self._na_value] * len(self))
#    1682             else:
# -> 1683                 result = _nanpercentile(values, qs * 100, axis=axis, **kw)
#    1684
#    1685         ndim = getattr(result, 'ndim', None) or 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _nanpercentile(values, q, axis, **kw)
#    1637                     return result
#    1638             else:
# -> 1639                 return np.percentile(values, q, axis=axis, **kw)
#    1640
#    1641         from pandas import Float64Index
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3538         raise ValueError("Percentiles must be in the range [0, 100]")
#    3539     return _quantile_unchecked(
# -> 3540         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3541
#    3542
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3650     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3651                     overwrite_input=overwrite_input,
# -> 3652                     interpolation=interpolation)
#    3653     if keepdims:
#    3654         return r.reshape(q.shape + k)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3248         keepdim = (1,) * a.ndim
#    3249
# -> 3250     r = func(a, **kwargs)
#    3251     return r, keepdim
#    3252
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3765             n = np.isnan(ap[-1:, ...])
#    3766
# -> 3767         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3768         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3769
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
DataTxt['DailyRate'].mean(axis = 0)
# Out:
# inf

# %%
print("Median is : " , DataTxt['DailyRate'].median())
# Out:
# Median is :  802.0

# %%
DataTxt['DailyRate'].var()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     467         avg = np.expand_dims(avg, axis)
# --> 468     sqr = _ensure_numeric((avg - values)**2)
#     469     np.putmask(sqr, mask, 0)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-bfb06930d1d2> in <module>
# ----> 1 DataTxt['DailyRate'].var()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#    9631                                       skipna=skipna, ddof=ddof)
#    9632         return self._reduce(f, name, axis=axis, numeric_only=numeric_only,
# -> 9633                             skipna=skipna, ddof=ddof)
#    9634
#    9635     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3219                                           'numeric_only.'.format(name))
#    3220             with np.errstate(all='ignore'):
# -> 3221                 return op(delegate, skipna=skipna, **kwds)
#    3222
#    3223         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     129             except Exception:
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#     133                     # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof)
#     466     if axis is not None:
#     467         avg = np.expand_dims(avg, axis)
# --> 468     sqr = _ensure_numeric((avg - values)**2)
#     469     np.putmask(sqr, mask, 0)
#     470     result = sqr.sum(axis=axis, dtype=np.float64) / d
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
plot = sns.countplot(x = "Attrition", data = DataTxt)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40);

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import matplotlib.pylab as plt
plt.plot(DataTxt["TotalWorkingYears"]);
